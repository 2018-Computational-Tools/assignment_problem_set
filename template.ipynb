# %% [markdown]
# # Template

# %% [markdown]
# # $\LaTeX$ Math
# This is just markdown that can include latex math.
#
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}

# %% [markdown]
# # System Info

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': '7f10f7bb3',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/Users/sk/anaconda3/envs/class/lib/python3.6/site-packages/IPython',
#  'ipython_version': '6.4.0',
#  'os_name': 'posix',
#  'platform': 'Darwin-17.2.0-x86_64-i386-64bit',
#  'sys_executable': '/Users/sk/anaconda3/envs/class/bin/python',
#  'sys_platform': 'darwin',
#  'sys_version': '3.6.5 |Anaconda custom (64-bit)| (default, Apr 26 2018, '
#                 '08:42:37) \n'
#                 '[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'}

# %% [markdown]
# # Custom Function

# %%
from scripts.functions import test_add
test_add(2, 5)
# Out:
# 7

# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
parabola = pd.DataFrame(np.arange(-50, 51), columns=list('x'))
parabola['err'] = np.random.normal(size=len(parabola), scale=5)
parabola['y'] = (parabola['x'] + parabola['err'])**2
parabola
# Out:
#       x        err            y
# 0   -50  -1.780770  2681.248111
# 1   -49  -4.114665  2821.167679
# 2   -48   2.136440  2103.466160
# 3   -47   4.576501  1799.753234
# 4   -46 -11.641919  3322.590850
# 5   -45  -1.884820  2198.186362
# 6   -44  -2.325864  2146.085650
# 7   -43   2.418214  1646.881394
# 8   -42   0.530274  1719.738184
# 9   -41   7.926562  1093.852280
# 10  -40  -3.184653  1864.914229
# 11  -39  10.503723   812.037775
# 12  -38 -12.559184  2556.231048
# 13  -37  -2.540296  1563.434990
# 14  -36  -2.330069  1469.194166
# 15  -35  -0.884396  1287.689874
# 16  -34   2.810491   972.785445
# 17  -33   2.156670   951.310999
# 18  -32  -1.607358  1129.454538
# 19  -31   1.272936   883.698351
# 20  -30   1.737286   798.781011
# 21  -29   4.217713   614.161753
# 22  -28  -3.017398   962.078983
# 23  -27   5.567161   459.366594
# 24  -26   1.280248   611.066115
# 25  -25  10.617030   206.869830
# 26  -24   9.906602   198.623878
# 27  -23   3.086148   396.561502
# 28  -22   5.278905   279.595007
# 29  -21   1.419137   383.410191
# ..   ..        ...          ...
# 71   21  -7.351788   186.273689
# 72   22  -8.897185   171.683771
# 73   23   2.822093   666.780482
# 74   24  -7.011571   288.606706
# 75   25  -5.042670   398.295015
# 76   26  -2.176624   567.553230
# 77   27   5.620688  1064.109314
# 78   28  -3.625504   594.116076
# 79   29   7.399474  1324.921717
# 80   30   5.932333  1291.132567
# 81   31   2.424623  1117.205420
# 82   32  -5.696410   691.878849
# 83   33   1.451198  1186.885057
# 84   34   6.093391  1607.479980
# 85   35  -6.926914   788.098174
# 86   36  -0.123058  1287.154982
# 87   37  -1.599961  1253.162742
# 88   38  -8.085758   894.861895
# 89   39  -2.058681  1364.661029
# 90   40  -2.112975  1435.426634
# 91   41   3.315390  1963.853761
# 92   42   6.061264  2309.885087
# 93   43   0.931154  1929.946279
# 94   44  10.549183  2975.613357
# 95   45  12.926589  3355.489715
# 96   46   6.297846  2735.064663
# 97   47  -1.161292  2101.187161
# 98   48  -1.506053  2161.687122
# 99   49   0.939718  2493.975480
# 100  50  -1.665747  2336.199969
#
# [101 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
parabola.plot.scatter(x = 'x', y = 'y')
