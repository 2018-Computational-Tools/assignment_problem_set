# %% [markdown]
# # Template

# %% [markdown]
# # $\LaTeX$ Math
# This is just markdown that can include latex math.
#
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}

# %% [markdown]
# # System Info

# %%
import IPython
print(IPython.sys_info())

# %% [markdown]
# # Custom Function

# %%
import os
exec(open(os.path.join("scripts", "functions.py")).read())
print(test_add(2, 5))
# Out:
# 7

# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
parabola = pd.DataFrame(np.arange(-50, 51), columns=list('x'))
parabola['err'] = np.random.normal(size=len(parabola), scale=5)
parabola['y'] = (parabola['x'] + parabola['err'])**2
parabola
# Out:
#       x        err            y
# 0   -50   3.701100  2143.588165
# 1   -49  -5.006386  2916.689771
# 2   -48   5.382021  1816.292111
# 3   -47   5.959540  1684.319344
# 4   -46  -5.375544  2639.446513
# 5   -45   1.741235  1871.320784
# 6   -44  -0.957106  2021.141408
# 7   -43   8.901111  1162.734230
# 8   -42   6.531701  1258.000267
# 9   -41  -5.176554  2132.274117
# 10  -40   1.241407  1502.228511
# 11  -39   2.406926  1339.053036
# 12  -38 -11.443789  2444.688288
# 13  -37  -4.014332  1682.175396
# 14  -36   4.060798  1020.112637
# 15  -35   3.059671  1020.184596
# 16  -34   7.997435   676.133371
# 17  -33  -7.088805  1607.112279
# 18  -32  -3.900767  1288.865086
# 19  -31   0.328669   940.730563
# 20  -30   6.636723   545.842710
# 21  -29   7.952530   442.995974
# 22  -28  -6.117840  1164.027002
# 23  -27  -7.139880  1165.531376
# 24  -26  -0.516268   703.112459
# 25  -25  -3.975405   839.574102
# 26  -24  -6.627557   938.047265
# 27  -23  -0.704358   561.896566
# 28  -22  -1.644274   559.051716
# 29  -21  -2.442587   549.554895
# ..   ..        ...          ...
# 71   21  -4.486150   272.707250
# 72   22   7.192733   852.215640
# 73   23  -0.668237   498.707622
# 74   24   0.049803   578.393041
# 75   25   3.070009   787.925379
# 76   26   0.089840   680.679776
# 77   27  -8.145534   355.490890
# 78   28  -0.615440   749.914123
# 79   29  -2.994425   676.289949
# 80   30  -1.526013   810.767927
# 81   31  11.125501  1774.557833
# 82   32   1.452317  1119.057523
# 83   33  -0.153576  1078.887595
# 84   34   0.591275  1196.556336
# 85   35  -4.509765   929.654411
# 86   36  -4.531965   990.237204
# 87   37   8.369798  2058.418558
# 88   38   4.625560  1816.938345
# 89   39  -2.769566  1312.644372
# 90   40   5.198653  2042.918204
# 91   41  -1.781065  1538.124835
# 92   42  -3.103915  1512.905422
# 93   43  -3.726696  1542.392396
# 94   44   5.080478  2408.893280
# 95   45   7.465478  2752.626426
# 96   46  -9.387088  1340.505307
# 97   47  -6.149848  1668.734884
# 98   48  -1.033696  2205.833701
# 99   49   2.215654  2623.043213
# 100  50  -1.056188  2395.496709
#
# [101 rows x 3 columns]

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
parabola.plot.scatter(x = 'x', y = 'y')
